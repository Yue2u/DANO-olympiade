# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\belol\\Documents\\DANO\\5 Kickstarter\\5 Kickstarter'

# %%
data = pd.read_csv("kickstarter_data.csv")
data['success_rate'] = data['pled'] / data['goal']

# %%
df = data
if 'Unnamed: 0' in df.columns or 'succsess' in df.columns:
    df = data.drop(columns=['Unnamed: 0', 'succsess'])
df['site'] = df['site'].fillna('')
df.shape
# Out:
# (8421, 37)

# %%
# Remove emissions
df = data
df = df[df['goal'] > 5]
df = df[df['created'] < 7.5]
df = df[df['period'] < 80]
df = df[df['n_vid'] < 10]


# Using 3 sigmas rule
n_sigmas = 3

created_std = df['created'].std() # Taken from description
created_mean = df['created'].mean()
df['created'] = df['created'][(df['created'] >= created_mean - created_std * n_sigmas) & (df['created'] <= created_mean + created_std * n_sigmas)]

# %%
df
# Out:
#       Unnamed: 0                                                URL  \
# 0           8438  https://www.kickstarter.com/projects/577038691...
# 1           3182  https://www.kickstarter.com/projects/200047954...
# 2           7977  https://www.kickstarter.com/projects/85660245/...
# 3           1270  https://www.kickstarter.com/projects/193393221...
# 4           6312  https://www.kickstarter.com/projects/148102341...
# ...          ...                                                ...
# 8416        8202  https://www.kickstarter.com/projects/501263634...
# 8417        3125  https://www.kickstarter.com/projects/154070452...
# 8418         322  https://www.kickstarter.com/projects/101642300...
# 8419        1098  https://www.kickstarter.com/projects/173840524...
# 8420         599  https://www.kickstarter.com/projects/youmadbro...
#
#            pled      goal        date  period status  text_am  n_img  n_vid  \
# 0         16.37  16368.00  2013-12-01      14  ended      355      7      0
# 1     124761.28   7278.02  2015-08-03      30  ended     2218     33      3
# 2       1211.00  35000.00  2013-04-12      31  ended     3174     19      3
# 3          1.00  10000.00  2013-11-13      14  ended      110      0      0
# 4       5415.00  67000.00  2016-04-25      30  ended     3955     46      1
# ...         ...       ...         ...     ...    ...      ...    ...    ...
# 8416    2246.00   7000.00  2014-03-11      60  ended      912     10      0
# 8417   18021.00  15000.00  2015-09-22      45  ended     1650     39      2
# 8418      14.00  10000.00  2016-02-17      30  ended      280     10      1
# 8419      82.88   3928.54  2014-05-31      31  ended      777      0      0
# 8420     568.18   1559.71  2015-06-30      30  ended      670     21      0
#
#       ...  indie  action  quest  adventure       mgp      cont  curr  \
# 0     ...      0       0      0          0  0.653856  0.276952   GBP
# 1     ...      0       1      0          0  6.105621  0.220415   AUD
# 2     ...      1       0      0          0  2.556285  0.289384   USD
# 3     ...      0       0      0          0  0.000000  0.000000   USD
# 4     ...      0       1      0          1  5.987628  0.256332   USD
# ...   ...    ...     ...    ...        ...       ...       ...   ...
# 8416  ...      1       0      1          0  3.246320  0.220351   USD
# 8417  ...      0       0      0          0  8.707396  0.230234   USD
# 8418  ...      0       0      0          0  2.763008  0.328798   USD
# 8419  ...      0       0      1          0  0.000000  0.000000   CAD
# 8420  ...      1       0      0          0  4.004428  0.216843   EUR
#
#       succsess is_site  success_rate
# 0            0       0      0.001000
# 1            1       1     17.142201
# 2            0       1      0.034600
# 3            0       1      0.000100
# 4            0       1      0.080821
# ...        ...     ...           ...
# 8416         0       1      0.320857
# 8417         1       1      1.201400
# 8418         0       0      0.001400
# 8419         0       0      0.021097
# 8420         0       0      0.364286
#
# [8334 rows x 39 columns]

# %%
X = df['success_rate']
X
# Out:
# 0        0.001000
# 1       17.142201
# 2        0.034600
# 3        0.000100
# 4        0.080821
#           ...
# 8416     0.320857
# 8417     1.201400
# 8418     0.001400
# 8419     0.021097
# 8420     0.364286
# Name: success_rate, Length: 8334, dtype: float64

# %%
n_clusters = 3

# %%
kmeans = KMeans(n_clusters=3)

# %%
print(kmeans.fit(X))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_600/4199259148.py in <module>
# ----> 1 print(kmeans.fit(X))
#
# D:\Programs\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     977             Fitted estimator.
#     978         """
# --> 979         X = self._validate_data(X, accept_sparse='csr',
#     980                                 dtype=[np.float64, np.float32],
#     981                                 order='C', copy=self.copy_x,
#
# D:\Programs\Anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# D:\Programs\Anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\Programs\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     692             # If input is 1D raise error
#     693             if array.ndim == 1:
# --> 694                 raise ValueError(
#     695                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     696                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1.00012219e-03 1.71422008e+01 3.46000000e-02 ... 1.40000000e-03
#  2.10968960e-02 3.64285668e-01].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
pre_y = kmeans.predict(X)
print(pre_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-31a6eb06293e> in <module>
# ----> 1 value_counts(pre_y)
#
# NameError: name 'value_counts' is not defined

# %%
fig, ax = plt.subplots()
ax.scatter(data['Internet'], data['Vaccinated'], alpha = 0.5, 
           c = pre_y)
