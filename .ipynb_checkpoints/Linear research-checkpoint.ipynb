# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import accuracy_score, roc_auc_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate, train_test_split
import numpy as np

# %%
data = pd.read_csv("kickstarter_data.csv")
data['success_rate'] = data['pled'] / data['goal']

# %%
df_1 = data[['text_am', 'success_rate']]

# %%
train_X, test_X, train_y, test_y = train_test_split(df_1['text_am'], df_1['success_rate'], train_size=0.8)

# %%
scaler = StandardScaler()

train_data = scaler.fit_transform(train_X.to_numpy().reshape(-1, 1))

model = LinearRegression()

model.fit(train_data, train_y)
model.predict(train_data)
# Out:
# array([ 8.74014904, 28.18810779, 23.17267388, ..., -5.83266765,
#        -5.07859892, -4.79801521])

# %%
def test_mse(model, X, y):
    preds = model.predict(X)
    mse = mean_squared_error(y, preds)
    
    return mse

# %%
test_mse(model, train_data, train_y)

test_x_data = scaler.transform(test_X.to_numpy().reshape(-1, 1))
test_y_data = test_y.to_numpy().reshape(-1, 1)

test_mse(model, train_data, train_y), test_mse(model, test_x_data, test_y_data)
# Out:
# (257693.1882442625, 24037.841292269262)

# %%
lasso = Lasso()
lasso.fit(train_data, train_y)

test_mse(lasso, train_data, train_y), test_mse(lasso, test_x_data, test_y_data)
# Out:
# (257694.1882442625, 24007.61925343779)

# %%
ridge = Ridge()
ridge.fit(train_data, train_y)

test_mse(ridge, train_data, train_y), test_mse(ridge, test_x_data, test_y_data)
# Out:
# (257693.18824992553, 24037.766963775084)

# %%
def test_models(train_x, train_y, test_x, test_y):
    scaler = StandardScaler()
    
    train_data = scaler.fit_transform(train_x.to_numpy().reshape(-1, 1))
    train_y = train_y.to_numpy().reshape(-1, 1)
    
    test_x = scaler.transform(test_x.to_numpy().reshape(-1, 1))
    test_y = test_y.to_numpy().reshape(-1, 1)
    
    model = LinearRegression()
    model.fit(train_data, train_y)
    linear_preds = model.predict(test_x)
    
    lasso = Lasso()
    lasso.fit(train_data, train_y)
    lasso_preds = lasso.predict(test_x)
    
    ridge = Ridge()
    ridge.fit(train_data, train_y)
    ridge_preds = ridge.predict(test_x)
    
    return mean_squared_error(linear_preds, test_y), mean_squared_error(lasso_preds, test_y), mean_squared_error(ridge_preds, test_y)

# %%
train_X, test_X, train_y, test_y = train_test_split(df_1['text_am'], df_1['success_rate'], train_size=0.8)

preds_by_pow = {}

for pow_ in np.linspace(0.1, 3, 15):
    preds_by_pow[f'^{pow_}'] = test_models(train_X ** pow_, train_y, test_X ** pow_, test_y)

# %%
preds = [(k, v) for k, v in preds_by_pow.items()]
preds.sort(key=lambda x: x[1][0])
preds
# Out:
# [('^0.1', (176.54557794392505, 157.91548104822934, 176.51363372273897)),
#  ('^0.30714285714285716',
#   (226.3161116368302, 202.40687744716215, 226.2690040219687)),
#  ('^0.5142857142857142',
#   (262.7927292213004, 235.83145390506976, 262.73470669646355)),
#  ('^0.7214285714285714',
#   (297.75548713787657, 268.14182621356383, 297.68711797339824)),
#  ('^0.9285714285714285',
#   (330.9677348383253, 298.9821275694829, 330.8896241436429)),
#  ('^1.1357142857142857',
#   (361.52960894888685, 327.43318349678, 361.44260571781)),
#  ('^1.342857142857143',
#   (388.5840325836928, 352.63344848944354, 388.4892194786843)),
#  ('^1.55', (411.4874955684716, 373.9343291572769, 411.3861279447944)),
#  ('^1.7571428571428571',
#   (429.85784203439516, 390.9442953547679, 429.7512734240526)),
#  ('^1.9642857142857142',
#   (443.5666303564015, 403.520969311885, 443.45624052796126)),
#  ('^3.0', (449.9614715698109, 407.02353389832274, 449.8501523649116)),
#  ('^2.1714285714285713',
#   (452.70167807929425, 411.7346766258876, 452.58881210912654)),
#  ('^2.7928571428571427',
#   (455.7053120537147, 413.04131397457553, 455.5921392369838)),
#  ('^2.3785714285714286',
#   (457.51598281827245, 415.818824488065, 457.4019049365185)),
#  ('^2.585714285714286',
#   (458.3743863624675, 416.1180594484403, 458.2602491121844))]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14,10))
plt.scatter(test_X ** 0.1, test_y)

# %%
data['n_img'].value_counts()
df = data[(data['goal'] >= 5) & (data['n_img'] > 0)]
# data['n_img'] = data['n_img'].apply(lambda x: 10e-5 if x == 0 else x) #  using log to get normal distribution showed that we should remove all zero elements

# %%
n_imgs = []

for v in df['n_img'].unique():
    s = df[df['n_img'] == v]['success_rate']
    
    if s.shape[0] > 5: 
        n_imgs.append((v, s.sum() / s.shape[0])) # amount imges, mean succes rate

# %%
n_imgs = sorted(n_imgs, key=lambda x: x[0], reverse=True)

xs = [k for k, v in n_imgs]
ys = [v for k, v in n_imgs]

plt.figure(figsize=(14,10))
plt.plot(xs, ys)
plt.xlabel = 'n_imgs'
plt.ylabel = 'mean succes score'

# %%
new_xs = []
new_ys = []

for i in range(1, len(n_imgs)):
    new_xs.append(n_imgs[i][0])
    new_ys.append(n_imgs[i][1] - n_imgs[i - 1][1])

# %%
plt.figure(figsize=(14,10))
plt.plot(new_xs, new_ys)
plt.xlabel = 'n_imgs'
plt.ylabel = 'mean succes score'

# %%
# hist for np.log(n_images)
np.log(df['n_img']).hist(bins=12)
# Out:
# <AxesSubplot:>

# %%
df  = df[df['text_am'] > 10]
np.log(df['text_am']).hist(bins=12)
# Out:
# <AxesSubplot:>

# %%
df['text_am'].max()
# Out:
# 6042

# %%
n_texts = []
n = 200
for v in range(1, df['text_am'].max(), n):
    s = df[(df['text_am'] >= v) & (df['text_am'] < v + n)]['success_rate']
    if s.shape[0] > 5: 
        n_texts.append((f'{int((v +v + n) / 2)}', v, s.sum() / s.shape[0]))

# %%
n_texts = sorted(n_texts, key=lambda x: x[1])
n_texts = sorted(n_texts, key=lambda x: x[2], reverse=True)
n_texts
# Out:
# [('4301', 4201, 2.1928545758957907),
#  ('901', 801, 1.566586745814526),
#  ('3701', 3601, 1.5290253196366719),
#  ('1501', 1401, 1.5013720904083894),
#  ('701', 601, 1.4608580720688358),
#  ('4501', 4401, 1.3801903055855704),
#  ('3901', 3801, 1.2542145967607683),
#  ('2901', 2801, 1.2171525920199102),
#  ('3101', 3001, 1.1537874335505767),
#  ('3301', 3201, 1.1372217168998195),
#  ('3501', 3401, 1.0573338232940714),
#  ('2101', 2001, 0.9955194613209789),
#  ('2701', 2601, 0.9883652364768827),
#  ('1701', 1601, 0.9423266728106627),
#  ('4701', 4601, 0.9270848622139823),
#  ('1101', 1001, 0.8747405526846085),
#  ('2301', 2201, 0.853852011084352),
#  ('4101', 4001, 0.8515540109531663),
#  ('1901', 1801, 0.8371242619957764),
#  ('501', 401, 0.8086905792767187),
#  ('2501', 2401, 0.7962983884461223),
#  ('1301', 1201, 0.7704737299627201),
#  ('301', 201, 0.5238559552236309),
#  ('101', 1, 0.35583220958640854)]

# %%
n_texts = sorted(n_texts, key=lambda x: x[1])

xs = [k for title, k, v in n_texts]
ys = [v for title, k, v in n_texts]

plt.figure(figsize=(14,10))
plt.plot(xs, ys, c='r')
plt.xlabel = 'n_imgs'
plt.ylabel = 'mean succes score'

# %%
new_xs = []
new_ys = []

for i in range(1, len(n_texts)):
    new_xs.append(n_texts[i][1])
    new_ys.append(n_texts[i][2] - n_texts[i - 1][2])

# %%
plt.figure(figsize=(14,10))
plt.plot(new_xs, new_ys)
plt.xlabel = 'n_imgs'
plt.ylabel = 'mean succes score'

# %%
def get_y(x, coeffs):
    y = 0
    for i in range(len(coeffs)):
        y += x**i * coeffs[-1 - i]
    return y

# %%
poly = np.polyfit(xs, ys, 7)

poly_xs = [i for i in range(4600)]
poly_ys= [get_y(i, poly) for i in range(4600)]

plt.figure(figsize=(14,10))

plt.plot(xs, ys, c='r', label='real')
plt.plot(poly_xs, poly_ys, label='poly')

plt.xlabel = 'n_imgs'
plt.ylabel = 'mean succes score'

plt.legend()

# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
import torch.nn.functional as F
from torch.optim import Adam
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9884/170581812.py in <module>
#       6 from torch.optim import Adam
#       7 from sklearn.metrics import accuracy_score
# ----> 8 from sklearn.preprocessing import train_test_split
#
# ImportError: cannot import name 'train_test_split' from 'sklearn.preprocessing' (D:\Programs\Anaconda\lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
data = pd.read_csv("kickstarter_data.csv")
data['success_rate'] = data['pled'] / data['goal']

# %%
df = data[data['goal'] >= 5]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'URL', 'pled', 'goal', 'date', 'period', 'status',
#        'text_am', 'n_img', 'n_vid', 'n_pled_t', 'min_pled_t', 'max_pled_t',
#        'mean_pled_t', 'step_pled_t', 'cr_time', 'backed', 'created', 'site',
#        'rpg', 'platformer', 'shooter', 'fighting', 'survival', 'horror',
#        'strategy', 'arcade', 'simulator', 'mmo', 'indie', 'action', 'quest',
#        'adventure', 'mgp', 'cont', 'curr', 'succsess', 'is_site',
#        'success_rate'],
#       dtype='object')

# %%
df.fillna(df.median())
# Out:
# C:\Users\belol\AppData\Local\Temp/ipykernel_14664/2553712938.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.median())
#       Unnamed: 0                                                URL  \
# 0           8438  https://www.kickstarter.com/projects/577038691...
# 1           3182  https://www.kickstarter.com/projects/200047954...
# 2           7977  https://www.kickstarter.com/projects/85660245/...
# 3           1270  https://www.kickstarter.com/projects/193393221...
# 4           6312  https://www.kickstarter.com/projects/148102341...
# ...          ...                                                ...
# 8416        8202  https://www.kickstarter.com/projects/501263634...
# 8417        3125  https://www.kickstarter.com/projects/154070452...
# 8418         322  https://www.kickstarter.com/projects/101642300...
# 8419        1098  https://www.kickstarter.com/projects/173840524...
# 8420         599  https://www.kickstarter.com/projects/youmadbro...
#
#            pled      goal        date  period status  text_am  n_img  n_vid  \
# 0         16.37  16368.00  2013-12-01      14  ended      355      7      0
# 1     124761.28   7278.02  2015-08-03      30  ended     2218     33      3
# 2       1211.00  35000.00  2013-04-12      31  ended     3174     19      3
# 3          1.00  10000.00  2013-11-13      14  ended      110      0      0
# 4       5415.00  67000.00  2016-04-25      30  ended     3955     46      1
# ...         ...       ...         ...     ...    ...      ...    ...    ...
# 8416    2246.00   7000.00  2014-03-11      60  ended      912     10      0
# 8417   18021.00  15000.00  2015-09-22      45  ended     1650     39      2
# 8418      14.00  10000.00  2016-02-17      30  ended      280     10      1
# 8419      82.88   3928.54  2014-05-31      31  ended      777      0      0
# 8420     568.18   1559.71  2015-06-30      30  ended      670     21      0
#
#       ...  indie  action  quest  adventure       mgp      cont  curr  \
# 0     ...      0       0      0          0  0.653856  0.276952   GBP
# 1     ...      0       1      0          0  6.105621  0.220415   AUD
# 2     ...      1       0      0          0  2.556285  0.289384   USD
# 3     ...      0       0      0          0  0.000000  0.000000   USD
# 4     ...      0       1      0          1  5.987628  0.256332   USD
# ...   ...    ...     ...    ...        ...       ...       ...   ...
# 8416  ...      1       0      1          0  3.246320  0.220351   USD
# 8417  ...      0       0      0          0  8.707396  0.230234   USD
# 8418  ...      0       0      0          0  2.763008  0.328798   USD
# 8419  ...      0       0      1          0  0.000000  0.000000   CAD
# 8420  ...      1       0      0          0  4.004428  0.216843   EUR
#
#       succsess is_site  success_rate
# 0            0       0      0.001000
# 1            1       1     17.142201
# 2            0       1      0.034600
# 3            0       1      0.000100
# 4            0       1      0.080821
# ...        ...     ...           ...
# 8416         0       1      0.320857
# 8417         1       1      1.201400
# 8418         0       0      0.001400
# 8419         0       0      0.021097
# 8420         0       0      0.364286
#
# [8405 rows x 39 columns]

# %%
def set_type(rate):
    type_ = 0
    for i in np.linspace(0, 1.75, 8):
        if rate < i + 0.25:
            return type_
        type_ += 1
    return 8

# %%
def get_type(n, start, stop, step):
    t = 0
    for i in range(start, stop, step):
        if n <= i + step:
            return t
    t += 1
    return t

# %%
# Add success type

types = []

for idx, row in df.iterrows():
    types.append(set_type(row[-1]))

types = pd.Series(types, dtype=int)
df = df.assign(succes_type=types.values)
if 'success_rate' in df.columns:
    df = df.drop(columns='success_rate')
if 'success' in df.columns:
    df = df.drop(columns='success')

# %%
numeric_data = df.corr().columns[1:]
target_col = df.corr().columns[-1]

print(numeric_data, target_col)

df = df[numeric_data]
target = df[target_col]
df, target
# Out:
# Index(['pled', 'goal', 'period', 'text_am', 'n_img', 'n_vid', 'n_pled_t',
#        'min_pled_t', 'max_pled_t', 'mean_pled_t', 'step_pled_t', 'cr_time',
#        'backed', 'created', 'rpg', 'platformer', 'shooter', 'fighting',
#        'survival', 'horror', 'strategy', 'arcade', 'simulator', 'mmo', 'indie',
#        'action', 'quest', 'adventure', 'mgp', 'cont', 'succsess', 'is_site',
#        'succes_type'],
#       dtype='object') succes_type
# (           pled      goal  period  text_am  n_img  n_vid  n_pled_t  \
#  0         16.37  16368.00      14      355      7      0         8
#  1     124761.28   7278.02      30     2218     33      3         5
#  2       1211.00  35000.00      31     3174     19      3        13
#  3          1.00  10000.00      14      110      0      0         3
#  4       5415.00  67000.00      30     3955     46      1        15
#  ...         ...       ...     ...      ...    ...    ...       ...
#  8416    2246.00   7000.00      60      912     10      0         8
#  8417   18021.00  15000.00      45     1650     39      2        23
#  8418      14.00  10000.00      30      280     10      1         9
#  8419      82.88   3928.54      31      777      0      0         7
#  8420     568.18   1559.71      30      670     21      0        10
#
#        min_pled_t  max_pled_t  mean_pled_t  ...  mmo  indie  action  quest  \
#  0           1.64     8184.00  1206.321250  ...    0      0       0      0
#  1           3.64       99.71    43.960000  ...    0      0       1      0
#  2           5.00     1000.00   312.692308  ...    0      1       0      0
#  3          25.00     1000.00   425.000000  ...    0      0       0      0
#  4           1.00     1000.00   165.866667  ...    0      0       1      0
#  ...          ...         ...          ...  ...  ...    ...     ...    ...
#  8416       10.00     1000.00   366.875000  ...    0      1       0      1
#  8417        1.00     8000.00   733.434783  ...    0      0       0      0
#  8418        1.00      200.00    67.888889  ...    0      0       0      0
#  8419        4.60       92.09    40.124286  ...    1      0       0      1
#  8420        3.34      222.82    60.494000  ...    0      1       0      0
#
#        adventure       mgp      cont  succsess  is_site  succes_type
#  0             0  0.653856  0.276952         0        0            0
#  1             0  6.105621  0.220415         1        1            8
#  2             0  2.556285  0.289384         0        1            0
#  3             0  0.000000  0.000000         0        1            0
#  4             1  5.987628  0.256332         0        1            0
#  ...         ...       ...       ...       ...      ...          ...
#  8416          0  3.246320  0.220351         0        1            1
#  8417          0  8.707396  0.230234         1        1            4
#  8418          0  2.763008  0.328798         0        0            0
#  8419          0  0.000000  0.000000         0        0            0
#  8420          0  4.004428  0.216843         0        0            1
#
#  [8405 rows x 33 columns],
#  0       0
#  1       8
#  2       0
#  3       0
#  4       0
#         ..
#  8416    1
#  8417    4
#  8418    0
#  8419    0
#  8420    1
#  Name: succes_type, Length: 8405, dtype: int32)

# %%
model = nn.Sequential(
    nn.Linear(32, 24),
    nn.ReLU(),
    nn.BatchNorm1d(24),
    nn.Linear(24, 20),
    nn.ReLU(),
    nn.Linear(20, 10))

optimizer = Adam(model.parameters())
loss_fn = F.cross_entropy

# %%
class MyDataset:
    def __init__(self, df):
        self.df = pd.DataFrame(data=df)
    
    def __len__(self):
        return self.df.shape[0]
    
    def __getitem__(self, i):
        return torch.Tensor(df.iloc[i])[:-1], torch.Tensor(df.iloc[i])[-1].to(torch.long)

# %%
from torch.utils.data import DataLoader


train, test = train_test_split(df, train_size=0.8)

train_loader = DataLoader(MyDataset(train), batch_size=24, shuffle=True)
test_loader = DataLoader(MyDataset(test), batch_size=24)

# %%
from tqdm.notebook import tqdm

# %%
model.train()

losses = []
accuracies = []

for epochs in tqdm(range(10)):
    epoch_losses = []
    epoch_accuracies = []
    for xb, yb in tqdm(train_loader):
        accuracy = 0
        correct_answers = 0
        
        optimizer.zero_grad()

        outp = model(xb)
        loss = loss_fn(outp, yb)

        loss.backward()
        optimizer.step()
        
        epoch_losses.append(loss.item())
        
        correct_answers = (outp.argmax(-1) == yb).sum()
        accuracy = correct_answers / xb.shape[0]
        epoch_accuracies.append(accuracy)
    
    losses.append(torch.tensor(epoch_losses).mean())
    accuracies.append(torch.tensor(epoch_accuracies).mean())
    
    print('loss:', losses[-1])
    print('accuracy: ', accuracies[-1])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/281 [00:00<?, ?it/s]
# loss: tensor(1.2254)
# accuracy:  tensor(0.6901)
#   0%|          | 0/281 [00:00<?, ?it/s]
# loss: tensor(0.6935)
# accuracy:  tensor(0.7762)
#   0%|          | 0/281 [00:00<?, ?it/s]
# loss: tensor(0.6176)
# accuracy:  tensor(0.8028)
#   0%|          | 0/281 [00:00<?, ?it/s]
# loss: tensor(0.5787)
# accuracy:  tensor(0.8117)
#   0%|          | 0/281 [00:00<?, ?it/s]
# loss: tensor(0.5473)
# accuracy:  tensor(0.8206)
#   0%|          | 0/281 [00:00<?, ?it/s]
# loss: tensor(0.5347)
# accuracy:  tensor(0.8160)
#   0%|          | 0/281 [00:00<?, ?it/s]
# loss: tensor(0.5189)
# accuracy:  tensor(0.8253)
#   0%|          | 0/281 [00:00<?, ?it/s]
# loss: tensor(0.4983)
# accuracy:  tensor(0.8304)
#   0%|          | 0/281 [00:00<?, ?it/s]
# loss: tensor(0.4991)
# accuracy:  tensor(0.8292)
#   0%|          | 0/281 [00:00<?, ?it/s]
# loss: tensor(0.5057)
# accuracy:  tensor(0.8247)

# %%
plt.figure(figsize=(14, 10))
plt.plot(range(epochs + 1), losses, label='loss')

plt.figure(figsize=(14, 10))
plt.plot(range(epochs + 1), accuracies, label='accuracy', c='r')

# %%
model.eval()

losses = []
accuracies = []

for xb, yb in test_loader:
    with torch.no_grad():
        outp = model(xb)
        correct_answers = (outp.argmax(-1) == yb).sum()
        accuracy = correct_answers / xb.shape[0]
        accuracies.append(accuracy)
torch.Tensor(accuracies).mean()
# Out:
# tensor(0.8234)

# %%
plt.figure(figsize=(14, 10))
plt.plot(np.arange(len(test_loader)), accuracies, label='accuracy', c='r')
